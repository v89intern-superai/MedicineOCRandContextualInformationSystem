# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
import easyocr
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = cv2.imread("../images/para.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.fastNlMeansDenoising(gray, h=12)
thresh = cv2.adaptiveThreshold(
    gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY, 15, 11
)
clean = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, np.ones((1, 1), np.uint8))

final = Image.fromarray(clean).convert("RGB")
final
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
reader = easyocr.Reader(['th','en'], gpu=False)
results = reader.readtext(clean)

for (bbox, text, prob) in results:
    print(f"{text} ({prob:.2f})")
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# iบ44น (0.05)
# yums (0.04)
# hn (0.98)
# ขือ (0.83)
# ตึกพิเศษ sv-1 (0.84)
# เตียง (0.79)
# วันที (0.59)
# l/l (0.28)
# 16:22 (1.00)
# 2า (0.68)
# prcetamol 5oo มก. เม็ด (pr) (0.23)
# รับประทาน ครังละ (0.76)
# เม็ด (0.77)
#  ห่างกันอย่างน้อย 6 ขัวโมง (0.40)
# เมือมีอาการ ใช้ลดไข้ แก้ปวด (0.51)
# ใข้ลดไข้ แก้ปวด (0.95)
# ชื่อสามัญ (0.47)
# พาราเซตามอล 5od มีลลีกรัม(ยาหลักแหงชารี (0.40)
# ห้ามใช้เกิน 8 เม็ดต่อวันเพราะอาจเป็นพิษต่ารับ (0.48)
# wee๔ (0.01)
# แsun (0.10)
# dw poa aseraa! (0.12)
# อยู่ภับยา (0.81)
# un ถdร (0.30)
# เด",~^=. (0.07)
# นตa! (0.46)
# ll (0.11)
# เ.ษเบ. (0.07)
# 25/09/:7 (0.85)
# วันเกิด (0.89)
# el ma (0.12)
